# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
# ...

# %%
# TODO
ds_sorted = ds.sort_values("price", ascending=False)

print(f"la casa on direccion en {ds_sorted['address'][0]} es la mas cara y u precio es {ds_sorted['price'][0]}")
# Out:
# la casa on direccion en Calle Presidente Felipe Gonzalez, Arganda del Rey es la mas cara y u precio es 195000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO

ds_sorted = ds.sort_values("price", ascending=False)
#la casa mas barata que no valga 0
ds_sorted = ds_sorted[ds_sorted['price'] > 0]

ds_ultima=ds_sorted.tail(1)
print(f"la casa on direccion en {ds_ultima['address'].values[0]} es la mas barata y u precio es {ds_ultima['price'].values[0]}")
# Out:
# la casa on direccion en Berlin, Coslada es la mas barata y u precio es 600

# %%
# Out:
#        Unnamed: 0  id_realEstates  isNew                   realEstate_name  \
# 1798         1799       142524805  False                    cyopsa sisocia
# 4605         4606       153929839  False                      torrecerredo
# 5013         5014       153990577  False                        particular
# 10292       10293       151594848  False  centro comercial inmobiliario 10
# 2049         2050       146493640  False                            majhol
# 8172         8173       150999741  False       living gestion de proyectos
# 8111         8112       153901156  False                           angeles
# 10297       10298       153586831  False                           asentis
# 4362         4363       149638983  False                 viviendas para ti
# 8256         8257       149639057  False                 viviendas para ti
# 4167         4168       146493649  False                            majhol
# ...

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
ds_sorted = ds.sort_values("surface", ascending=False)
print(f"La casa mas grande esta ubicada en {ds_sorted['address'][0]} y tiene {ds_sorted['surface'][0]} metros cuadrados")
print(f"La casa mas pequena esta ubicada en {ds_sorted['address'][15328]} y tiene {ds_sorted['surface'][15328]} metros cuadrados")
# Out:
# La casa mas grande esta ubicada en Calle Presidente Felipe Gonzalez, Arganda del Rey y tiene 103.0 metros cuadrados
# La casa mas pequena esta ubicada en Calle de Manuela Malasaña,  Madrid Capital y tiene nan metros cuadrados

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
print(list(ds["level5"].unique()))
# Out:
# ['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte', 'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón', 'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón', 'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes', 'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles', 'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra', 'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón', 'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez', 'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva', 'San Martín de la Vega', 'Villalbilla', 'Collado Villalba', 'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete', 'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo', 'Valdemorillo', 'Fuente El Saz de Jarama', 'Tres Cantos', 'Arroyomolinos (Madrid)', 'Griñón', 'Paracuellos de Jarama', 'Guadarrama', 'Titulcia', 'Galapagar', '
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
#
print(ds.notnull().all())
            


for i in ds.columns:
    if "NAs"  in ds[i]:
        print("esta en la columna" + i)
#el valor NAs no esta en ninguna columna
# Out:
# Unnamed: 0           True
# id_realEstates       True
# isNew                True
# realEstate_name     False
# phone_realEstate    False
# url_inmueble         True
# rooms               False
# bathrooms           False
# surface             False
# price                True
# date                 True
# description         False
# address              True
# country              True
# level1               True
# level2               True
# level3               True
# level4              False
# level5               True
# level6              False
# level7              False
# level8              False
# upperLevel           True
# countryId            True
# level1Id             True
# level2Id             True
# level3Id             True
# level4Id             True
# level5Id             True
# level6Id             True
# level7Id             True
# level8Id             True
# accuracy             True
# latitude             True
# longitude            True
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
print("Dimensiones originales:", ds.shape)
ds = ds.drop(columns=["zipCode","customZone"])
print("Dimensiones después de eliminar NAs:", ds.shape)
# Out:
# Dimensiones originales: (15335, 37)
# Dimensiones después de eliminar NAs: (15335, 35)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
import numpy as np
precio_medio=[]
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Arroyomolinos (Madrid)":
        precio_medio.append((ds["price"][i]))


print(np.mean(precio_medio))
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt
plt.hist(precio_medio, bins=20)
plt.show()

# %% [markdown]
# las informacion que se puede obtener del histograma es que la los precios se comportan paracido a una normal y que hay 4 precios que mas se repiten

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
precio_medio_V=[]
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Valdemorillo":
        precio_medio_V.append((ds["price"][i]))
precio_medio_G=[]
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Galapagar":
        precio_medio_G.append((ds["price"][i]))


print(np.mean(precio_medio_V))
print(np.mean(precio_medio_G))
print("la diferencia de precio entre Valdemorillo y Galapagar es de " + str(np.mean(precio_medio_V)-np.mean(precio_medio_G)))
# Out:
# 363860.2931034483
# 360063.20238095237
# la diferencia de precio entre Valdemorillo y Galapagar es de 3797.090722495923

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

print(ds.columns)
ds["pps"]=ds["price"]/ds["surface"]
ds["pps"].dropna()
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Galapagar":
        precio_medio_G.append((ds["pps"][i]))

for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Valdemorillo":
        if ds["pps"][i]!=None:
            precio_medio_V.append((ds["pps"][i]))

precio_medio_V = [x for x in precio_medio_V if not np.isnan(x)]
print(np.sum(precio_medio_V))  # Resultado: 7
precio_medio_G = [x for x in precio_medio_G if not np.isnan(x)]
print(np.sum(precio_medio_G))  # Resultado: 7
print("la diferencia de precio por metro cuadrado entre Valdemorillo y Galapagar es de " + str(abs(np.mean(precio_medio_V)-np.mean(precio_medio_G))))
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude'],
#       dtype='object')
# 21173748.361177832
# 30365783.302273206
# la diferencia de precio por metro cuadrado entre Valdemorillo y Galapagar es de 225.27945634600474

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
#analiza la superficie y el precio de las casas 
plt.scatter( ds["price"],ds["surface"])
#plt.xlim([0, 9])
plt.ylim([0,5000] ) # Establece el rango del eje x entre 100 y 500
plt.show()

# %% [markdown]
# la mayor parte de las casas tiene un precio por metro cuadrado parecido, salvo algunas que su precio se dispara, no parece haber una relacion lineal, parece depender de otro factor

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
print(len(ds["realEstate_name"].unique()))
# Out:
# 1822

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

mas_frecuente = ds["level5"].value_counts().idxmax()
print("La población con más casas es:", mas_frecuente)
cantidad = ds["level5"].value_counts().max()
print("Cantidad de casas:", cantidad)
# Out:
# La población con más casas es:  Madrid Capital
# Cantidad de casas: 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
# TODO

cinturon_sur = ds[ds["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
cinturon_sur["level5"].unique()
# Out:
# array(['Fuenlabrada', 'Alcorcón', 'Leganés', 'Getafe'], dtype=object)

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code

mediana_precios = cinturon_sur.groupby("level5")["price"].median()
mediana_precios.plot(kind='bar')
plt.ylabel('Mediana de Precios')
plt.title('Mediana de Precios por Localidad en el Cinturón Sur de Madrid')
plt.show()

# %% [markdown]
# la mediana de precios en getafe es superior a las del resto de las poblaciones, por lo que parece que en promedio las viviendas cuestan mas ahi

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
variables=["price","rooms","surface","bathrooms"]
for var in variables:
    media =cinturon_sur[var].mean()
    varianza= cinturon_sur[var].var()
    print(f"Variable: {var}, Media: {media}, Varianza: {varianza}")
# Out:
# Variable: price, Media: 223094.48070562293, Varianza: 14921367508.04902
# Variable: rooms, Media: 3.0177383592017737, Varianza: 0.7188858892927542
# Variable: surface, Media: 111.75222363405337, Varianza: 4263.051760316337
# Variable: bathrooms, Media: 1.633221850613155, Varianza: 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
for poblacion in cinturon_sur["level5"].unique():
    casa_mas_cara = cinturon_sur[cinturon_sur["level5"] == poblacion].sort_values("price", ascending=False).iloc[0]
    print(f"La casa más cara en {poblacion} está en {casa_mas_cara['address']} con un precio de {casa_mas_cara['price']}")
# Out:
# La casa más cara en Fuenlabrada está en Calle de Paulo Freire, 5, Fuenlabrada con un precio de 490000
# La casa más cara en Alcorcón está en Alcorcón con un precio de 950000
# La casa más cara en Leganés está en Avenida Reina Sofía, Leganés con un precio de 650000
# La casa más cara en Getafe está en Getafe con un precio de 1050000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO

import seaborn as sns
plt.figure(figsize=(10, 6))
for poblacion in cinturon_sur["level5"].unique():
    subset = cinturon_sur[cinturon_sur["level5"] == poblacion]
    precios_normalizados = (subset["price"] /ds["price"].mean()) 
    sns.histplot(precios_normalizados, label=poblacion, bins=20)
    legend = plt.legend(title='Población')

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
#### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)

#Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores
ds["pps"]=ds["price"]/ds["surface"]
ds["pps"].dropna()
precio_medio_G=[]
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Getafe":
        precio_medio_G.append((ds["pps"][i]))
precio_medio_A=[]
for i in range(len(ds["level5"])):
    if ds["level5"][i] == "Alcorcón":
        precio_medio_A.append((ds["pps"][i]))
precio_medio_A = [x for x in precio_medio_A if not np.isnan(x)]
precio_medio_G = [x for x in precio_medio_G if not np.isnan(x)]
print(np.sum(precio_medio_G))
print(np.sum(precio_medio_A))
print("la diferencia de precio por metro cuadrado entre Getafe y Alcorcón es de " + str(abs(np.mean(precio_medio_G)-np.mean(precio_medio_A))))
# Out:
# 497981.9027696026
# 387399.3290745339
# la diferencia de precio por metro cuadrado entre Getafe y Alcorcón es de 172.98753094815493

# %% [markdown]
# si bien el promedio de precios es muy parecido,la distribucion de precios en general. si bien getafe tiene mayor cantidad de propiedades y algunas a mayores precios, esta sigue manteniendo un promedio parecido al de alarcon.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

import seaborn as sns
plt.figure(figsize=(10, 6))
for poblacion in cinturon_sur["level5"].unique():
    subset = cinturon_sur[cinturon_sur["level5"] == poblacion]
    precios_normalizados = (subset["price"] /ds["price"].mean()) 
    sns.histplot(precios_normalizados, label=poblacion, bins=20)
    legend = plt.legend(title='Población')

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
from ipyleaflet import Marker, MarkerCluster
markers = []
for i in range(len(cinturon_sur)):
    marker = Marker(location=(cinturon_sur.iloc[i]['latitude'], cinturon_sur.iloc[i]['longitude']),
                    title=cinturon_sur.iloc[i]['level5'])
    markers.append(marker)
marker_cluster = MarkerCluster(markers=markers)
map.add_layer(marker_cluster)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…
